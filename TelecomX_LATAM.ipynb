# %% [markdown]
# # 📌 Extracción

# %% [markdown]
# ## ✅ Cargar los datos directamente desde la API utilizando Python.

# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
df = pd.read_json('TelecomX_Data.json')

# %% [markdown]
# ## ✅ Convertir los datos a un DataFrame de Pandas para facilitar su manipulación.

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 🔧 Transformación

# %% [markdown]
# Ahora que has extraído los datos, es fundamental comprender la estructura del dataset y el significado de sus columnas. Esta etapa te ayudará a identificar qué variables son más relevantes para el análisis de evasión de clientes.
#
# 📌 Para facilitar este proceso, hemos creado un diccionario de datos con la descripción de cada columna. Aunque no es obligatorio utilizarlo, puede ayudarte a comprender mejor la información disponible.
#
# 🔗 Enlace al diccionario y a la API
#
# ¿Qué debes hacer?
#
# - ✅ Explorar las columnas del dataset y verificar sus tipos de datos.
# - ✅ Consultar el diccionario para comprender mejor el significado de las variables.
# - ✅ Identificar las columnas más relevantes para el análisis de evasión.
#
# 📌 Tips:
# - 🔗 [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html) de DataFrame.info()
# - 🔗 [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html) de DataFrame.dtypes

# %% [markdown]
# ## ✅ Explorar las columnas del dataset y verificar sus tipos de datos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# ## ✅ Identificar las columnas más relevantes para el análisis de evasión.

# %%
df.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %% [markdown]
# ## Comprobación de incoherencias en los datos

# %% [markdown]
# En este paso, verifica si hay problemas en los datos que puedan afectar el análisis. Presta atención a valores ausentes, duplicados, errores de formato e inconsistencias en las categorías. Este proceso es esencial para asegurarte de que los datos estén listos para las siguientes etapas.
#
# 📌 Tips:
#
# 🔗 [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.unique.html) de pandas.unique()
#
# 🔗 [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.normalize.html) de pandas.Series.dt.normalize()

# %%
df.Churn.unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %% [markdown]
# ## Normalize para desglosar todo

# %%
df = pd.json_normalize(
    df.to_dict(orient='records'),
    sep='_'
)

# %%
df.head(1)
# Out:
#    customerID Churn customer_gender  customer_SeniorCitizen customer_Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
#
#   customer_Dependents  customer_tenure phone_PhoneService phone_MultipleLines  \
# 0                 Yes                9                Yes                  No
#
#   internet_InternetService internet_OnlineSecurity internet_OnlineBackup  \
# 0                      DSL                      No                   Yes
#
#   internet_DeviceProtection internet_TechSupport internet_StreamingTV  \
# 0                        No                  Yes                  Yes
#
#   internet_StreamingMovies account_Contract account_PaperlessBilling  \
# 0                       No         One year                      Yes
#
#   account_PaymentMethod  account_Charges_Monthly account_Charges_Total
# 0          Mailed check                     65.6                 593.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
#  13  internet_TechSupport       7267 non-null   object
#  14  internet_StreamingTV       7267 non-null   object
#  15  internet_StreamingMovies   7267 non-null   object
#  16  account_Contract           7267 non-null   object
#  17  account_PaperlessBilling   7267 non-null   object
#  18  account_PaymentMethod      7267 non-null   object
#  19  account_Charges_Monthly    7267 non-null   float64
#  20  account_Charges_Total      7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Ver todas las columnas

# %%
pd.set_option('display.max_columns', None)

# Puedes volver a ocultarlas así:
# pd.reset_option('display.max_columns')

# %%
df.sample(10)
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 1178  1684-FLBGS    No          Female                       0
# 2989  4140-TOILV                  Male                       0
# 6230  8570-KLJYJ    No          Female                       0
# 3698  5095-ETBRJ    No          Female                       0
# 7052  9711-FJTBX    No            Male                       0
# 973   1370-AQYEM                  Male                       0
# 6274  8630-QSGXK    No            Male                       0
# 3584  4937-QPZPO    No            Male                       0
# 4998  6838-YAUVY    No          Female                       0
# 6313  8681-ICONS    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 1178              Yes                 Yes               23                Yes
# 2989              Yes                  No               22                Yes
# 6230               No                  No               36                Yes
# 3698              Yes                  No               55                Yes
# 7052              Yes                 Yes               56                Yes
# 973               Yes                 Yes                5                Yes
# 6274              Yes                  No               51                Yes
# 3584              Yes                 Yes               61                Yes
# 4998               No                  No               54                Yes
# 6313              Yes                 Yes               29                Yes
#
#      phone_MultipleLines internet_InternetService internet_OnlineSecurity  \
# 1178                 Yes                      DSL                      No
# 2989                  No              Fiber optic                      No
# 6230                 Yes                      DSL                     Yes
# 3698                  No                      DSL                     Yes
# 7052                  No              Fiber optic                      No
# 973                   No              Fiber optic                     Yes
# 6274                 Yes                      DSL                      No
# 3584                 Yes              Fiber optic                      No
# 4998                 Yes              Fiber optic                      No
# 6313                  No                       No     No internet service
#
#      internet_OnlineBackup internet_DeviceProtection internet_TechSupport  \
# 1178                   Yes                        No                  Yes
# 2989                    No                       Yes                   No
# 6230                    No                        No                   No
# 3698                   Yes                        No                  Yes
# 7052                   Yes                       Yes                  Yes
# 973                     No                       Yes                   No
# 6274                    No                        No                  Yes
# 3584                    No                       Yes                   No
# 4998                    No                       Yes                  Yes
# 6313   No internet service       No internet service  No internet service
#
#      internet_StreamingTV internet_StreamingMovies account_Contract  \
# 1178                  Yes                       No   Month-to-month
# 2989                  Yes                       No   Month-to-month
# 6230                   No                       No         One year
# 3698                   No                       No         Two year
# 7052                   No                       No         One year
# 973                    No                      Yes   Month-to-month
# 6274                  Yes                      Yes         Two year
# 3584                  Yes                      Yes         One year
# 4998                   No                      Yes         Two year
# 6313  No internet service      No internet service   Month-to-month
#
#      account_PaperlessBilling      account_PaymentMethod  \
# 1178                      Yes    Credit card (automatic)
# 2989                      Yes  Bank transfer (automatic)
# 6230                       No               Mailed check
# 3698                       No               Mailed check
# 7052                      Yes               Mailed check
# 973                       Yes               Mailed check
# 6274                      Yes  Bank transfer (automatic)
# 3584                      Yes           Electronic check
# 4998                      Yes  Bank transfer (automatic)
# 6313                      Yes               Mailed check
#
#       account_Charges_Monthly account_Charges_Total
# 1178                    69.50                1652.1
# 2989                    87.00               1850.65
# 6230                    54.45                1893.5
# 3698                    56.80               3112.05
# 7052                    85.85                4793.8
# 973                     90.35                 434.5
# 6274                    75.20               3901.25
# 3584                    99.90               6241.35
# 4998                    95.10               5064.85
# 6313                    20.65                654.85

# %%
df.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer_gender              0
# customer_SeniorCitizen       0
# customer_Partner             0
# customer_Dependents          0
# customer_tenure              0
# phone_PhoneService           0
# phone_MultipleLines          0
# internet_InternetService     0
# internet_OnlineSecurity      0
# internet_OnlineBackup        0
# internet_DeviceProtection    0
# internet_TechSupport         0
# internet_StreamingTV         0
# internet_StreamingMovies     0
# account_Contract             0
# account_PaperlessBilling     0
# account_PaymentMethod        0
# account_Charges_Monthly      0
# account_Charges_Total        0
# dtype: int64

# %% [markdown]
# ## Manejo de inconsistencias

# %% [markdown]
# Ahora que has identificado las inconsistencias, es momento de aplicar las correcciones necesarias. Ajusta los datos para asegurarte de que estén completos y coherentes, preparándolos para las siguientes etapas del análisis.
#
# [Documentación](Pandas%20manipulacion%20de%20datos/manipulacion_datos.ipynb) Celda 21, 50, 54

# %%
# Lista de columnas que pueden tener "No internet service"
cols_internet = [
    'internet_OnlineSecurity', 'internet_OnlineBackup', 'internet_DeviceProtection',
    'internet_TechSupport', 'internet_StreamingTV', 'internet_StreamingMovies'
]

# Reemplazar "No internet service" por "No" en esas columnas
for col in cols_internet:
    df[col] = df[col].replace('No internet service', 'No')

# %%
# Lista de columnas que pueden tener "No internet service"
cols_internet = [
    'phone_MultipleLines'
]

# Reemplazar "No phone service" por "No" en esas columnas
for col in cols_internet:
    df[col] = df[col].replace('No phone service', 'No')

# %%
df.tail(10)
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 7257  9975-SKRNR    No            Male                       0
# 7258  9978-HYCIN    No            Male                       1
# 7259  9979-RGMZT    No          Female                       0
# 7260  9985-MWVIX   Yes          Female                       0
# 7261  9986-BONCE   Yes          Female                       0
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 7257               No                  No                1                Yes
# 7258              Yes                 Yes               47                Yes
# 7259               No                  No                7                Yes
# 7260               No                  No                1                Yes
# 7261               No                  No                4                Yes
# 7262               No                  No               13                Yes
# 7263              Yes                  No               22                Yes
# 7264               No                  No                2                Yes
# 7265              Yes                 Yes               67                Yes
# 7266              Yes                 Yes               63                 No
#
#      phone_MultipleLines internet_InternetService internet_OnlineSecurity  \
# 7257                  No                       No                      No
# 7258                  No              Fiber optic                      No
# 7259                  No              Fiber optic                      No
# 7260                  No              Fiber optic                      No
# 7261                  No                       No                      No
# 7262                  No                      DSL                     Yes
# 7263                 Yes              Fiber optic                      No
# 7264                  No                      DSL                      No
# 7265                  No                      DSL                     Yes
# 7266                  No                      DSL                     Yes
#
#      internet_OnlineBackup internet_DeviceProtection internet_TechSupport  \
# 7257                    No                        No                   No
# 7258                   Yes                        No                   No
# 7259                   Yes                        No                   No
# 7260                    No                        No                   No
# 7261                    No                        No                   No
# 7262                    No                        No                  Yes
# 7263                    No                        No                   No
# 7264                   Yes                        No                   No
# 7265                    No                       Yes                  Yes
# 7266                   Yes                       Yes                   No
#
#      internet_StreamingTV internet_StreamingMovies account_Contract  \
# 7257                   No                       No   Month-to-month
# 7258                  Yes                       No         One year
# 7259                  Yes                      Yes         One year
# 7260                   No                       No   Month-to-month
# 7261                   No                       No   Month-to-month
# 7262                   No                       No         One year
# 7263                   No                      Yes   Month-to-month
# 7264                   No                       No   Month-to-month
# 7265                   No                      Yes         Two year
# 7266                  Yes                      Yes         Two year
#
#      account_PaperlessBilling      account_PaymentMethod  \
# 7257                       No               Mailed check
# 7258                      Yes  Bank transfer (automatic)
# 7259                      Yes               Mailed check
# 7260                      Yes               Mailed check
# 7261                       No  Bank transfer (automatic)
# 7262                       No               Mailed check
# 7263                      Yes           Electronic check
# 7264                      Yes               Mailed check
# 7265                       No               Mailed check
# 7266                       No           Electronic check
#
#       account_Charges_Monthly account_Charges_Total
# 7257                    18.90                  18.9
# 7258                    84.95               4018.05
# 7259                    94.05                633.45
# 7260                    70.15                 70.15
# 7261                    20.95                  85.5
# 7262                    55.15                 742.9
# 7263                    85.10                1873.7
# 7264                    50.30                 92.75
# 7265                    67.85               4627.65
# 7266                    59.00                3707.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
#  13  internet_TechSupport       7267 non-null   object
#  14  internet_StreamingTV       7267 non-null   object
#  15  internet_StreamingMovies   7267 non-null   object
#  16  account_Contract           7267 non-null   object
#  17  account_PaperlessBilling   7267 non-null   object
#  18  account_PaymentMethod      7267 non-null   object
#  19  account_Charges_Monthly    7267 non-null   float64
#  20  account_Charges_Total      7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
df['account_Charges_Total'] = df['account_Charges_Total'].str.replace('[ ]','')

# %%
df['account_Charges_Total'] = df['account_Charges_Total'].str.replace(r'\s+', '', regex=True)

# %%
df['account_Charges_Total'] = df['account_Charges_Total'].replace('', np.nan)

# %%
df['account_Charges_Total'] = df['account_Charges_Total'].astype(np.float64)

# %%
df.isnull().sum()
# Out:
# customerID                    0
# Churn                         0
# customer_gender               0
# customer_SeniorCitizen        0
# customer_Partner              0
# customer_Dependents           0
# customer_tenure               0
# phone_PhoneService            0
# phone_MultipleLines           0
# internet_InternetService      0
# internet_OnlineSecurity       0
# internet_OnlineBackup         0
# internet_DeviceProtection     0
# internet_TechSupport          0
# internet_StreamingTV          0
# internet_StreamingMovies      0
# account_Contract              0
# account_PaperlessBilling      0
# account_PaymentMethod         0
# account_Charges_Monthly       0
# account_Charges_Total        11
# dtype: int64

# %%
df['account_Charges_Total'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: account_Charges_Total
# Non-Null Count  Dtype
# --------------  -----
# 7256 non-null   float64
# dtypes: float64(1)
# memory usage: 56.9 KB

# %% [markdown]
# ## Cambia valores nulos vacios

# %%
df['account_Charges_Total'] = df['account_Charges_Total'].fillna(0)

# %%
df['account_Charges_Total'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head(1)
# Out:
#    customerID Churn customer_gender  customer_SeniorCitizen customer_Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
#
#   customer_Dependents  customer_tenure phone_PhoneService phone_MultipleLines  \
# 0                 Yes                9                Yes                  No
#
#   internet_InternetService internet_OnlineSecurity internet_OnlineBackup  \
# 0                      DSL                      No                   Yes
#
#   internet_DeviceProtection internet_TechSupport internet_StreamingTV  \
# 0                        No                  Yes                  Yes
#
#   internet_StreamingMovies account_Contract account_PaperlessBilling  \
# 0                       No         One year                      Yes
#
#   account_PaymentMethod  account_Charges_Monthly  account_Charges_Total
# 0          Mailed check                     65.6                  593.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
#  13  internet_TechSupport       7267 non-null   object
#  14  internet_StreamingTV       7267 non-null   object
#  15  internet_StreamingMovies   7267 non-null   object
#  16  account_Contract           7267 non-null   object
#  17  account_PaperlessBilling   7267 non-null   object
#  18  account_PaymentMethod      7267 non-null   object
#  19  account_Charges_Monthly    7267 non-null   float64
#  20  account_Charges_Total      7267 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Columna de cuentas diarias

# %% [markdown]
# Ahora que los datos están limpios, es momento de crear la columna **"Cuentas_Diarias"**. Utiliza la facturación mensual para calcular el valor diario, proporcionando una visión más detallada del comportamiento de los clientes a lo largo del tiempo.
#
# **📌 Esta columna te ayudará a profundizar en el análisis y a obtener información valiosa para las siguientes etapas.**

# %%
df.sample(10)
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 5813  7954-MLBUN    No            Male                       0
# 2846  3948-KXDUF    No            Male                       0
# 2608  3640-JQGJG    No            Male                       0
# 4177  5727-MYATE    No            Male                       0
# 2372  3315-IKYZQ    No            Male                       0
# 6992  9626-WEQRM    No          Female                       0
# 147   0236-HFWSV   Yes            Male                       0
# 2301  3205-MXZRA    No            Male                       0
# 3179  4439-YRNVD    No          Female                       0
# 5581  7629-WFGLW    No          Female                       1
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 5813               No                  No               31                Yes
# 2846               No                  No               66                Yes
# 2608              Yes                 Yes               13                Yes
# 4177              Yes                 Yes               72                Yes
# 2372              Yes                 Yes               28                 No
# 6992               No                  No                4                 No
# 147                No                  No               15                Yes
# 2301               No                  No               26                Yes
# 3179               No                  No               10                 No
# 5581              Yes                  No               56                Yes
#
#      phone_MultipleLines internet_InternetService internet_OnlineSecurity  \
# 5813                  No              Fiber optic                      No
# 2846                 Yes                      DSL                     Yes
# 2608                  No                      DSL                      No
# 4177                 Yes                      DSL                     Yes
# 2372                  No                      DSL                     Yes
# 6992                  No                      DSL                     Yes
# 147                  Yes              Fiber optic                      No
# 2301                  No                      DSL                      No
# 3179                  No                      DSL                      No
# 5581                 Yes              Fiber optic                     Yes
#
#      internet_OnlineBackup internet_DeviceProtection internet_TechSupport  \
# 5813                    No                       Yes                  Yes
# 2846                   Yes                       Yes                  Yes
# 2608                    No                        No                   No
# 4177                   Yes                       Yes                  Yes
# 2372                    No                       Yes                  Yes
# 6992                    No                        No                   No
# 147                     No                        No                   No
# 2301                    No                        No                  Yes
# 3179                   Yes                        No                  Yes
# 5581                   Yes                       Yes                  Yes
#
#      internet_StreamingTV internet_StreamingMovies account_Contract  \
# 5813                  Yes                      Yes         Two year
# 2846                   No                       No         Two year
# 2608                   No                       No   Month-to-month
# 4177                  Yes                      Yes         Two year
# 2372                  Yes                       No         One year
# 6992                   No                       No   Month-to-month
# 147                   Yes                      Yes   Month-to-month
# 2301                  Yes                       No         One year
# 3179                   No                       No   Month-to-month
# 5581                   No                       No         One year
#
#      account_PaperlessBilling      account_PaymentMethod  \
# 5813                       No  Bank transfer (automatic)
# 2846                       No  Bank transfer (automatic)
# 2608                       No  Bank transfer (automatic)
# 4177                      Yes    Credit card (automatic)
# 2372                       No               Mailed check
# 6992                      Yes               Mailed check
# 147                       Yes           Electronic check
# 2301                       No    Credit card (automatic)
# 3179                       No           Electronic check
# 5581                       No           Electronic check
#
#       account_Charges_Monthly  account_Charges_Total
# 5813                    99.45                3109.90
# 2846                    68.75                4447.55
# 2608                    44.80                 559.20
# 4177                    90.80                6397.60
# 2372                    50.80                1386.80
# 6992                    29.15                 110.05
# 147                     93.35                1444.65
# 2301                    59.45                1507.00
# 3179                    36.25                 374.00
# 5581                    95.65                5471.75

# %%
df['estimated_daily_charge']=round((df['account_Charges_Monthly']/30),2)

# %%
df.sample(10)
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 4610  6322-HRPFA    No            Male                       0
# 1976  2801-NISEI    No            Male                       0
# 3523  4854-CIDCF    No          Female                       1
# 1171  1670-SVOWZ   Yes          Female                       0
# 4526  6202-JVYEU    No            Male                       0
# 739   1058-CIYUA                Female                       1
# 6695  9220-ZNKJI    No          Female                       1
# 1746  2480-JZOSN    No          Female                       0
# 6003  8204-TIFGJ    No          Female                       0
# 6225  8564-LDKFL    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 4610              Yes                 Yes               49                Yes
# 1976               No                  No               24                Yes
# 3523               No                  No                3                Yes
# 1171              Yes                 Yes               14                Yes
# 4526               No                  No                9                Yes
# 739               Yes                  No               52                Yes
# 6695              Yes                  No               55                Yes
# 1746              Yes                  No                1                Yes
# 6003               No                  No               23                Yes
# 6225              Yes                  No               40                Yes
#
#      phone_MultipleLines internet_InternetService internet_OnlineSecurity  \
# 4610                  No                      DSL                     Yes
# 1976                  No                      DSL                     Yes
# 3523                  No              Fiber optic                      No
# 1171                  No              Fiber optic                      No
# 4526                  No                       No                      No
# 739                  Yes              Fiber optic                      No
# 6695                  No              Fiber optic                      No
# 1746                  No                       No                      No
# 6003                  No                       No                      No
# 6225                 Yes              Fiber optic                      No
#
#      internet_OnlineBackup internet_DeviceProtection internet_TechSupport  \
# 4610                   Yes                        No                  Yes
# 1976                    No                        No                  Yes
# 3523                    No                       Yes                   No
# 1171                   Yes                        No                  Yes
# 4526                    No                        No                   No
# 739                    Yes                       Yes                   No
# 6695                    No                       Yes                  Yes
# 1746                    No                        No                   No
# 6003                    No                        No                   No
# 6225                   Yes                       Yes                   No
#
#      internet_StreamingTV internet_StreamingMovies account_Contract  \
# 4610                   No                       No   Month-to-month
# 1976                   No                       No   Month-to-month
# 3523                   No                       No   Month-to-month
# 1171                   No                      Yes   Month-to-month
# 4526                   No                       No         One year
# 739                   Yes                      Yes         One year
# 6695                  Yes                       No         Two year
# 1746                   No                       No   Month-to-month
# 6003                   No                       No   Month-to-month
# 6225                  Yes                      Yes         One year
#
#      account_PaperlessBilling      account_PaymentMethod  \
# 4610                       No    Credit card (automatic)
# 1976                       No           Electronic check
# 3523                       No           Electronic check
# 1171                      Yes    Credit card (automatic)
# 4526                      Yes           Electronic check
# 739                       Yes           Electronic check
# 6695                       No    Credit card (automatic)
# 1746                      Yes               Mailed check
# 6003                      Yes  Bank transfer (automatic)
# 6225                      Yes  Bank transfer (automatic)
#
#       account_Charges_Monthly  account_Charges_Total  estimated_daily_charge
# 4610                    59.60                2970.30                    1.99
# 1976                    54.95                1348.50                    1.83
# 3523                    73.85                 196.40                    2.46
# 1171                    89.65                1208.35                    2.99
# 4526                    19.90                 164.60                    0.66
# 739                    106.50                5621.85                    3.55
# 6695                    88.80                4805.30                    2.96
# 1746                    20.65                  20.65                    0.69
# 6003                    20.30                 470.60                    0.68
# 6225                   106.00                4178.65                    3.53

# %% [markdown]
# ## Estandarización y transformación de datos (opcional)

# %% [markdown]
# La **estandarización y transformación de datos** es una etapa opcional, pero altamente recomendada, ya que busca hacer que la información sea más **consistente, comprensible y adecuada para el análisis**. Durante esta fase, por ejemplo, puedes convertir valores textuales como **"Sí" y "No"** en valores binarios **(1 y 0)**, lo que facilita el procesamiento matemático y la aplicación de modelos analíticos.
#
# Además, **traducir o renombrar columnas y datos** hace que la información sea más accesible y fácil de entender, especialmente cuando se trabaja con fuentes externas o términos técnicos. Aunque no es un paso obligatorio, puede mejorar significativamente la **claridad y comunicación de los resultados**, facilitando la interpretación y evitando confusiones, especialmente al compartir información con **stakeholders no técnicos**.

# %%
df.sample(10)
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 5711  7802-EFKNY   Yes            Male                       0
# 7086  9761-XUJWD    No            Male                       0
# 6264  8623-TMRBY   Yes            Male                       1
# 4653  6371-NZYEG    No            Male                       0
# 4210  5787-KXGIY    No            Male                       0
# 3192  4456-RHSNB    No          Female                       0
# 3414  4726-DLWQN    No            Male                       1
# 1799  2560-WBWXF    No            Male                       0
# 621   0883-EIBTI   Yes          Female                       0
# 4371  5995-LFTLE    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 5711              Yes                  No                5                 No
# 7086               No                  No                5                Yes
# 6264              Yes                 Yes               51                Yes
# 4653              Yes                 Yes               16                Yes
# 4210              Yes                  No               72                Yes
# 3192              Yes                 Yes               19                Yes
# 3414               No                  No               50                Yes
# 1799               No                  No               68                Yes
# 621                No                  No                2                Yes
# 4371               No                  No               58                Yes
#
#      phone_MultipleLines internet_InternetService internet_OnlineSecurity  \
# 5711                  No                      DSL                      No
# 7086                  No                      DSL                      No
# 6264                 Yes              Fiber optic                      No
# 4653                  No                      DSL                     Yes
# 4210                  No                       No                      No
# 3192                  No                      DSL                      No
# 3414                 Yes                      DSL                     Yes
# 1799                 Yes                       No                      No
# 621                   No                       No                      No
# 4371                 Yes                       No                      No
#
#      internet_OnlineBackup internet_DeviceProtection internet_TechSupport  \
# 5711                    No                        No                   No
# 7086                   Yes                        No                  Yes
# 6264                   Yes                       Yes                   No
# 4653                    No                       Yes                   No
# 4210                    No                        No                   No
# 3192                    No                       Yes                   No
# 3414                   Yes                        No                   No
# 1799                    No                        No                   No
# 621                     No                        No                   No
# 4371                    No                        No                   No
#
#      internet_StreamingTV internet_StreamingMovies account_Contract  \
# 5711                   No                       No   Month-to-month
# 7086                   No                      Yes   Month-to-month
# 6264                   No                       No   Month-to-month
# 4653                  Yes                       No         Two year
# 4210                   No                       No         Two year
# 3192                   No                       No   Month-to-month
# 3414                  Yes                       No   Month-to-month
# 1799                   No                       No         Two year
# 621                    No                       No   Month-to-month
# 4371                   No                       No         Two year
#
#      account_PaperlessBilling      account_PaymentMethod  \
# 5711                      Yes           Electronic check
# 7086                      Yes  Bank transfer (automatic)
# 6264                      Yes           Electronic check
# 4653                       No               Mailed check
# 4210                       No    Credit card (automatic)
# 3192                      Yes  Bank transfer (automatic)
# 3414                      Yes  Bank transfer (automatic)
# 1799                      Yes  Bank transfer (automatic)
# 621                        No               Mailed check
# 4371                      Yes    Credit card (automatic)
#
#       account_Charges_Monthly  account_Charges_Total  estimated_daily_charge
# 5711                    24.95                 100.40                    0.83
# 7086                    65.60                 339.90                    2.19
# 6264                    84.20                4146.05                    2.81
# 4653                    64.25                1024.00                    2.14
# 4210                    19.30                1304.80                    0.64
# 3192                    49.60                 962.90                    1.65
# 3414                    70.35                3454.60                    2.34
# 1799                    24.15                1498.85                    0.80
# 621                     19.50                  31.55                    0.65
# 4371                    25.30                1474.35                    0.84

# %% [markdown]
# 🛡️ Recomendación de seguridad extra (para evitar errores en ambos casos):
#
# Antes de convertir, puedes verificar si hay valores distintos a "Yes" y "No":

# %%
for col in cols_internet:
    print(f"{col}: {df[col].unique()}")
# Out:
# phone_MultipleLines: ['No' 'Yes']

# %% [markdown]
# ✅ Alternativa más directa con .map():
#
# ✔️ Ventajas:
#
# Más directa.
#
# Más rápida con datos grandes.
#
# No lanza advertencias.
#
# No convierte a string temporalmente.
#
# 🔸 Desventaja menor: Si hay valores inesperados (como 'N/A', 'Unknown', etc.), map() pondrá NaN.

# %%
# Lista de columnas que pueden tener "No internet service"
cols_internet = [
    'customer_Partner', 'customer_Dependents', 'phone_PhoneService',
    'phone_MultipleLines', 'internet_OnlineSecurity', 'internet_OnlineBackup',
    'internet_DeviceProtection', 'internet_TechSupport', 'internet_StreamingTV',
    'internet_StreamingMovies','account_PaperlessBilling'
]

# Cambio de variable y cambio de tipo de vatiable usando map

for col in cols_internet:
    df[col] = df[col].map({'No': 0, 'Yes': 1}).astype(int)

# %%
df.sample(1)
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 5583  7632-MNYOY   Yes            Male                       1
#
#       customer_Partner  customer_Dependents  customer_tenure  \
# 5583                 0                    0               66
#
#       phone_PhoneService  phone_MultipleLines internet_InternetService  \
# 5583                   1                    1              Fiber optic
#
#       internet_OnlineSecurity  internet_OnlineBackup  \
# 5583                        0                      1
#
#       internet_DeviceProtection  internet_TechSupport  internet_StreamingTV  \
# 5583                          1                     1                     1
#
#       internet_StreamingMovies account_Contract  account_PaperlessBilling  \
# 5583                         1         One year                         0
#
#         account_PaymentMethod  account_Charges_Monthly  account_Charges_Total  \
# 5583  Credit card (automatic)                    110.9                7432.05
#
#       estimated_daily_charge
# 5583                     3.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   int64
#  5   customer_Dependents        7267 non-null   int64
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   int64
#  8   phone_MultipleLines        7267 non-null   int64
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   int64
#  11  internet_OnlineBackup      7267 non-null   int64
#  12  internet_DeviceProtection  7267 non-null   int64
#  13  internet_TechSupport       7267 non-null   int64
#  14  internet_StreamingTV       7267 non-null   int64
#  15  internet_StreamingMovies   7267 non-null   int64
#  16  account_Contract           7267 non-null   object
#  17  account_PaperlessBilling   7267 non-null   int64
#  18  account_PaymentMethod      7267 non-null   object
#  19  account_Charges_Monthly    7267 non-null   float64
#  20  account_Charges_Total      7267 non-null   float64
#  21  estimated_daily_charge     7267 non-null   float64
# dtypes: float64(3), int64(13), object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# ### reenombrar columnas de un data frame

# %%
df = df.rename(columns={
    'nombre_viejo1': 'nombre_nuevo1',
    'nombre_viejo2': 'nombre_nuevo2'
})

# %% [markdown]
# # 📊 Carga y análisis

# %% [markdown]
# # 📄Informe final
