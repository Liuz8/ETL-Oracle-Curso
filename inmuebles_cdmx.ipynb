# %% [markdown]
# # **PANDAS**

# %% [markdown]
# ## **Importando la base de datos**

# %%
import pandas as pd

url = 'alquiler.csv'

pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
datos = pd.read_csv(url, sep=';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head() # Primeras 5
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail() # Ultimas 5
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(10) # Primeras 10
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.sample(10)    # Muestra de 10 aleatoria
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 17112  Conjunto Comercial/Sala          Santa Fe             0        6
# 15041             Departamento          Santa Fe             1        1
# 18521             Departamento           Condesa             3        2
# 7255              Departamento           Condesa             3        4
# 14020             Departamento          Santa Fe             3        2
# 10792             Departamento          Santa Fe             3        2
# 20507  Conjunto Comercial/Sala  Centro Histórico             0        0
# 10278             Departamento           Condesa             1        0
# 6752              Departamento         Del Valle             2        2
# 18691             Departamento              Roma             2        1
#
#        Suites  Area    Valor  Condominio  Impuesto
# 17112       0   219  52500.0     25970.0    5845.0
# 15041       1    65   7000.0      5425.0    1225.0
# ...

# %%
type(datos) # Tipo de datos (Es un pandas DataFrame)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Exploracion inicial de los datos

# %%
datos.sample(5)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 13629             Departamento              Coyoacán             2        1
# 17723    Departamento en Hotel              Santa Fe             1        1
# 20178             Departamento  Bosques de las Lomas             2        1
# 7564              Departamento               Condesa             3        0
# 19750  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 13629       2    85  35000.0     13650.0    1050.0
# 17723       0    45  13300.0         NaN       NaN
# 20178       1    76  15750.0      3307.5    1141.0
# 7564        0   103   8750.0      4704.0     574.0
# 19750       0   194  22750.0     15872.5    1092.0

# %%
datos.shape # Muestra una tupla, numero de filas y columnas de la tabla
# Out:
# (25121, 9)

# %%
datos.columns # Muestra un array con las columnas de la tabla
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info() # Muestra información de la tabla
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo'] # Devuelve una serie pandas
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones', 'Valor']] # Devuelve un DataFrame
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# # Bloque 2

# %% [markdown]
# ## **Demandas de Machine Learning**

# %% [markdown]
# ### **¿Cuáles son los valores promedio de alquiler por tipo de propiedad?**

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos['Valor'].mean() # Promerio de todas la filas en Valor
# Out:
# np.float64(36885.05048392878)

# %%
# Agrupa el Tipo de Vivienda y obten el promedio de su Valor
datos.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
# agrupa por tipo y valor
datos.groupby('Tipo')['Valor'].mean(numeric_only=True)
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
# Mejora visual y organizar de forma ascendente

df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean(numeric_only=True).sort_values('Valor')
df_tipo_precio
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
# Graficar  kind es para barras horizontales, figsize es para el tamaño de la figura
df_tipo_precio.plot(kind='barh', figsize=(12,8), color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón',
                         'Casa Comercial', 'Terreno Estándar','Cochera/Estacionamiento',
                         'Galpón/Depósito/Almacén','Tienda en Centro Comercial','Hotel',
                         'Loteo/Condominio','Industria']

# %%
# Consultar si algunos de mis elementos de mi lista 'inmuebles_comerciales' esta dentro de mi dataset
datos.query('@inmuebles_comerciales in Tipo')
#Devuelve un data frame
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
#Se hace lo mismo pero en negacion para consultar lo contrario, osea los inmuebles no comerciales
datos.query('@inmuebles_comerciales not in Tipo')
#Devuelve un data frame
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
#Los query son basicamente condicionales para manipulas los datos dentro de un data frame
df = datos.query('@inmuebles_comerciales not in Tipo')
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
#Se copia la celda 49 y se modifica para que se use el nuevo dataframe (df) con inmuebles residenciales
df_tipo_precio = df.groupby('Tipo')[['Valor']].mean(numeric_only=True).sort_values('Valor')
df_tipo_precio.plot(kind='barh', figsize=(12,8), color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ### ¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?

# %%
#el unique muestra un array con el nombre de cada columna
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
# Se utiliza el siguiente metodo para contar la ocurrencia de cada uno de ellos, osea con cual frecuencia estan
df.Tipo.value_counts()

# El método value_counts() en Pandas sirve para contar cuántas veces aparece cada valor único en una columna.
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %% [markdown]
# ### ¿Para qué se usa value_counts?
# - Ver frecuencias de respuestas (como cuántos aprobaron/reprobaron).
# - Saber cuántas veces se repite un valor.
# - Ver distribución de categorías rápidamente.

# %%
# usa value_counts pero para que muestre los porcentajes
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
# Graficar los porcentajes por tipo
# kind bar es el tipo de grafica barras verticales, figzise(12,8) es el tamaño de la grafica,
# xlabel es una etiqeta para el eje x, ylabel es una etiqueta para el eje y
porcentaje_tipo = df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind='bar', figsize=(12,8), color='green', xlabel='Titulo', ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Titulo', ylabel='Porcentaje'>

# %%
#filtra solo los departamentos de df
df.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.query('Tipo == "Departamento"')
df.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
df.shape
# Out:
# (14764, 9)

# %% [markdown]
# ### Cambiar el nombre a un dato en un data frame
#
# Cuando trabajamos con bases de datos, en ocasiones puede ser necesario cambiar los nombres de las columnas. Por ejemplo, cuando creamos el siguiente DataFrame en nuestro proyecto:
#
# ```python
# df['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')
#
# Obtuvimos el siguiente resultado:

# %% [markdown]
# ![cambio de columna](img/cambia_nombre_columna.JPG)

# %% [markdown]
# Podemos ver que la columna con los porcentajes está nombrada como "Tipo". ¿Y si quisiéramos cambiar su nombre a "Porcentajes"?
#
# En ese caso, podemos utilizar el método rename() para cambiar el nombre de esa columna. Este método nos permite especificar un diccionario que asocia el nombre antiguo de la columna con el nuevo nombre que deseamos asignar. Entonces, hagámoslo:
#
# ```python
# # Guardando el DataFrame en una variable
# df_ejemplo = df['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')
#
# # Cambiando el nombre de la columna "Tipo" a "Porcentajes"
# df_ejemplo.rename(columns={'Tipo': 'Porcentajes'}, inplace=True)
#
# # Visualizando el DataFrame
# df_ejemplo
#
# Hemos utilizado el parámetro inplace=True para que este cambio se aplique definitivamente en nuestro DataFrame df_ejemplo. Entonces, al visualizar el DataFrame, obtendremos el siguiente resultado:

# %% [markdown]
# ![columnas](img/columnas.JPG)

# %% [markdown]
# ¡Y listo! Ahora también sabemos cómo cambiar nombres de columnas en un DataFrame.

# %% [markdown]
# ## Tarea Bloque 2
#
# El equipo de ML ha llegado con algunas demandas de última hora que debemos resolver en este momento de análisis exploratorio. Estas demandas son las siguientes:
#
# 1. Calcular el promedio de habitaciones por departamento.
# 2. Verificar cuántas colonias únicas existen en nuestra base de datos.
# 3. Analizar qué colonias tienen el promedio de alquiler más alto.
# 4. Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.
#
# Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

# %%
# tarea 1.
df['Habitaciones'].mean()
# Out:
# np.float64(2.5041994039555675)

# %%
# tarea 2
df.Colonia.value_counts()
# Out:
# Colonia
# Santa Fe                       3344
# Condesa                        2552
# Coyoacán                       1768
# Lomas de Chapultepec           1241
# Narvarte                       1064
#                                ...
# San Sebastián                     1
# Los Alpes                         1
# San Juan Xalpa                    1
# Residencial Emiliano Zapata       1
# Pedregal                          1
# Name: count, Length: 83, dtype: int64

# %%
# tarea 3 Analizar qué colonias tienen el promedio de alquiler más alto.

df_alquiler_alto = df.groupby('Colonia')[['Valor']].mean(numeric_only=True).sort_values('Valor')
df_alquiler_alto
# Out:
#                                   Valor
# Colonia
# Potrero de San Bernardino   1190.000000
# Santa María Aztahuacán      1785.000000
# San Antonio Tecomitl        2065.000000
# El Rodeo                    2275.000000
# Tláhuac                     2275.000000
# ...                                 ...
# Lomas de Chapultepec       30232.165189
# Roma                       32530.388539
# Coyoacán                   33205.218609
# Bosques de Aragón          35948.718750
# Los Alpes                  54250.000000
#
# [83 rows x 1 columns]

# %%
# tarea 4 Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.

grafico_alquiler_alto = df_alquiler_alto.tail()
grafico_alquiler_alto.plot(kind='barh', figsize=(12,8), color='purple')
# Out:
# <Axes: ylabel='Colonia'>

# %% [markdown]
# # Bloque 3

# %% [markdown]
# ## Verificar los datos nulos

# %%
# como saber cuantos datos nulos hay
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
# sumar las cantidades de nulos
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %% [markdown]
# ### Cambiar los valores nulos por 0

# %%
df.fillna(0)
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
# cambia el data frame por el dataframe sin nulos

df = df.fillna(0)
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ## Remover registros inconsistentes
